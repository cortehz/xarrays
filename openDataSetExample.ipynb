# %%
import xarray as xr

# open_dataset lazy loads the data and variables loaded when accessed
dataSet = xr.tutorial.open_dataset('air_temperature')

# %%
# get attributes suggestion/completion on tab in jupyter notebook
dataSet
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 25, time: 2920, lon: 53)
# Coordinates:
#   * lat      (lat) float32 75.0 72.5 70.0 67.5 65.0 ... 25.0 22.5 20.0 17.5 15.0
#   * lon      (lon) float32 200.0 202.5 205.0 207.5 ... 322.5 325.0 327.5 330.0
#   * time     (time) datetime64[ns] 2013-01-01 ... 2014-12-31T18:00:00
# Data variables:
#     air      (time, lat, lon) float32 ...
# Attributes:
#     Conventions:  COARDS
#     title:        4x daily NMC reanalysis (1948)
#     description:  Data is from NMC initialized reanalysis\n(4x/day).  These a...
#     platform:     Model
#     references:   http://www.esrl.noaa.gov/psd/data/gridded/data.ncep.reanaly...

# %%
#get dimensions corresponding to the algebraic dimensions
airT.dims
# Out:
# ('time', 'lat', 'lon')

# %%
#mapping of dimension names -> size
airT.sizes
# Out:
# Frozen({'time': 2920, 'lat': 25, 'lon': 53})

# %%
airT = dataSet['air']

partyT = airT.loc['2014-01-01']

partyT
# Out:
# <xarray.DataArray 'air' (time: 4, lat: 25, lon: 53)>
# array([[[252.29999, 251.2    , ..., 241.59999, 243.2    ],
#         [252.39   , 252.79999, ..., 238.29999, 242.29999],
#         ...,
#         [298.19998, 298.1    , ..., 295.6    , 294.69998],
#         [298.29   , 298.6    , ..., 295.29   , 294.69998]],
#
#        [[252.5    , 251.2    , ..., 241.5    , 243.2    ],
#         [253.5    , 253.59999, ..., 239.29999, 242.59999],
#         ...,
#         [297.69998, 297.5    , ..., 295.19998, 294.79   ],
#         [297.9    , 298.     , ..., 295.     , 294.69998]],
#
#        [[252.89   , 251.39   , ..., 243.89   , 245.89   ],
#         [254.59999, 254.5    , ..., 241.2    , 244.7    ],
#         ...,
#         [297.29   , 297.     , ..., 295.5    , 295.19998],
#         [297.29   , 297.1    , ..., 295.69998, 295.1    ]],
#
#        [[252.7    , 251.2    , ..., 244.2    , 245.09999],
#         [254.7    , 254.59999, ..., 243.89   , 246.5    ],
#         ...,
# ...
